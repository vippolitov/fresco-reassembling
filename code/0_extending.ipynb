# %%
import numpy as np
import matplotlib.pyplot as plt

from utils import build_fragment
from extend import extend_fragment, load_model
# Out:
# Detectron v2 is not installed

# %%
model = load_model()

# %%
# %matplotlib inline

# %%
fr = build_fragment(9, None, ext_step=20)

# %%
inv_mask = np.invert(fr.mask.astype(bool))
plt.imshow(inv_mask[:,:,0], cmap='gray')
plt.show()

# %%
res = extend_fragment(fr.fragment * 255, inv_mask, model) * fr.extended_mask
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))
axes[0].imshow(fr.fragment)
axes[1].imshow(res)
plt.show()
